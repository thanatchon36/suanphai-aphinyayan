# %%
#Default
import pandas as pd
pd.options.display.float_format = '{:,}'.format
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
def reset(df):
    cols = df.columns
    return df.reset_index()[cols]
def print_counts(df):
    cols = df.columns
    for each in cols:
        print(each)
        print(df[each].value_counts())
        print('______________________________________')

# ~
#Default Ending

print('OK')
# Out:
# OK

# %%
data = [
    
    {"first_name": "คุณศรัณย์", "last_name": "ธำรงรัตน์ (งานโครงสร้างและฐานราก)", "donation_amount": 10007},
    {"first_name": "คุณวรางคณา", "last_name": "ธำรงรัตน์ (งานหล่อขึ้นรูปองค์พระ)", "donation_amount": 10006},
    {"first_name": "คุณพราว", "last_name": "ธำรงรัตน์ (งานตกแต่งพื้นผิว)", "donation_amount": 10005},
    
    {"first_name": "คุณณัฐวัฒน์", "last_name": "เมืองจีน", "donation_amount": 10004},
    {"first_name": "คุณธนะรัชฏ์", "last_name": "พฤกษ์พระกานต์", "donation_amount": 7000},
    {"first_name": "คุณสืบพงษ์", "last_name": "ชัยวนนท์", "donation_amount": 5010},
    {"first_name": "คุณวีริศ", "last_name": "จันทราทิพย์", "donation_amount": 5009},
    {"first_name": "คุณสคุณพจน์", "last_name": "ธนาโรจน์โสภณ", "donation_amount": 5008},
    {"first_name": "คุณธนัชชนม์", "last_name": "จงมั่นคง", "donation_amount": 5007},
    {"first_name": "คุณนิธิพัฒน์", "last_name": "ภัททกัป", "donation_amount": 5006},
    {"first_name": "คุณรัตนาวดี", "last_name": "ศรีงาม", "donation_amount": 5005},
    {"first_name": "คุณสุปวีร์", "last_name": "รัตนจิตต์ดำรง", "donation_amount": 5004},
    {"first_name": "คุณวัชราภรณ์", "last_name": "สิทธิ์สว่างโสภณ", "donation_amount": 5004},
    
    
    {"first_name": "คุณสมัย", "last_name": "มีลา", "donation_amount": 5003},
    {"first_name": "คุณอุทุมพร", "last_name": "ทีพายุพรรค", "donation_amount": 5002},
    {"first_name": "คุณอุไรบุญ", "last_name": "ประสิทธิ์", "donation_amount": 5001},
    

    {"first_name": "ครอบครัวเชิดไชยธำรง", "last_name": "", "donation_amount": 5000},
    {"first_name": "คุณสุวิมล", "last_name": "อัศวธรรมรัตน์", "donation_amount": 5000},
    {"first_name": "คุณปริญญา", "last_name": "คำสุข", "donation_amount": 5000},
    
    
    {"first_name": "คุณรุ่ง", "last_name": "มัลลิกะมาส", "donation_amount": 3003},
    {"first_name": "คุณบุษกร", "last_name": "ธีระปัญญาชัย", "donation_amount": 3002},
    {"first_name": "คุณภาณุวัฒน์", "last_name": "พุฒพรึก (อุทิศให้น้องธนพล พุฒพรึก)", "donation_amount": 3001},
    {"first_name": "คุณศิวัช", "last_name": "พึ่งเจษฎา", "donation_amount": 3001},
    {"first_name": "คุณนัชนัญ", "last_name": "สิทธิ (อุทิศให้คุณแม่รัศมี สิทธิ)", "donation_amount": 3001},
    {"first_name": "คุณปิยาภรณ์", "last_name": "สิงห์ทอง", "donation_amount": 3001},
    {"first_name": "คุณโสภณ", "last_name": "หัตถกิจจำเริญ", "donation_amount": 3001},
    {"first_name": "คุณเกตุสุชา", "last_name": "จรรยากูล", "donation_amount": 3001},
    {"first_name": "คุณณัฐิกานต์", "last_name": "โพธิ์ไพฑูรย์", "donation_amount": 3000.3},
    {"first_name": "คุณคารม", "last_name": "วรสง่าศิลป์", "donation_amount": 3000.2},
    {"first_name": "คุณศุภรดา", "last_name": "วรสง่าศิลป์", "donation_amount": 3000.1},
    {"first_name": "คุณทศพร", "last_name": "รุจิยากร", "donation_amount": 3001},
    {"first_name": "ครอบครัวสุริยะอมาตยวดี", "last_name": "", "donation_amount": 3001},

    {"first_name": "พระมหาครรชิต", "last_name": "สุชิตคนฺโธ", "donation_amount": 2007}, # 0
    {"first_name": "พระประพันธ์", "last_name": "ปัญญาธโร", "donation_amount": 2006}, # 2000
    {"first_name": "พระสุนทร", "last_name": "พจน์ธนาบันเทิง สุนทโร", "donation_amount": 2005}, # 1000
    {"first_name": "พระธวัชชัย", "last_name": "กิติชัยวัฒน์ (อภิธโช)", "donation_amount": 2004}, # 1000
    {"first_name": "พระพรพิพัฒน์", "last_name": "สายบุญสา", "donation_amount": 2004}, # 500
    {"first_name": "พระธนพล", "last_name": "ธนพโล", "donation_amount": 2003}, # 369
    {"first_name": "คุณอรปภา", "last_name": "กาญจนาคม", "donation_amount": 1000},
    {"first_name": "คุณกนกกาญจน์", "last_name": "เหลี่ยมพันธุ์", "donation_amount": 1000},
    {"first_name": "คุณปรเมษฐ", "last_name": "วิสุทธิธรรม", "donation_amount": 1050},
    {"first_name": "คุณเฉลิมเกียรติ", "last_name": "สิรชัยรัตน์", "donation_amount": 1000},
    {"first_name": "คุณธนกฤต", "last_name": "วิลาสมงคลชัย", "donation_amount": 1000},
    {"first_name": "คุณดนยา", "last_name": "ทนงจิตร", "donation_amount": 1000},
    {"first_name": "คุณสุสาคร", "last_name": "มิ่งมูล", "donation_amount": 1000},     
    {"first_name": "คุณศิริพร", "last_name": "สุคันธมาลา", "donation_amount": 1000},
    {"first_name": "คุณเจน", "last_name": "สาระคุณ", "donation_amount": 1500}, 
    {"first_name": "คุณรมิตา", "last_name": "สุทธินรากร", "donation_amount": 1000},
    {"first_name": "คุณสุวัชชัย", "last_name": "ใจข้อ", "donation_amount": 1000},
    {"first_name": "คุณภัทร", "last_name": "สุขวารี", "donation_amount": 1000},
    {"first_name": "คุณชัยพิทักษ์", "last_name": "พัฒนกิตติคุณ", "donation_amount": 1000},
    {"first_name": "คุณสุนันทา", "last_name": "ลีเลิศพันธ์", "donation_amount": 2000},
    {"first_name": "คุณสุรัตน์", "last_name": "ขุนทอง", "donation_amount": 1000},
    {"first_name": "คุณธชทิต", "last_name": "ล้อเลิศสกุล", "donation_amount": 1000},
    {"first_name": "คุณจิระเดช", "last_name": "เกิดศรี", "donation_amount": 1000},
    {"first_name": "คุณอารีย์", "last_name": "สวรรค์พิทักษ์", "donation_amount": 1000},
    {"first_name": "คุณศรัณย์", "last_name": "ทรงศิริโสภิณ", "donation_amount": 1000},
    {"first_name": "คุณกัลยาณี", "last_name": "รังสิพล", "donation_amount": 1000},
    {"first_name": "คุณปนัสยา", "last_name": "แก้วผาบ", "donation_amount": 1000},
    {"first_name": "คุณชลิศา", "last_name": "แดงจำรูญ", "donation_amount": 1000},
    {"first_name": "คุณวิกรานต์", "last_name": "นาคะศิริ", "donation_amount": 1500},
    {"first_name": "คุณพัชรพร", "last_name": "เลิศพงศาภรณ์", "donation_amount": 1000},
    {"first_name": "คุณพจมาน", "last_name": "พิศาลประภา", "donation_amount": 2000},
    {"first_name": "คุณธนกฤต", "last_name": "คำหอม", "donation_amount": 1000},
    {"first_name": "คุณชาดา", "last_name": "ลิมป์กิตติสิน", "donation_amount": 1000},
    {"first_name": "คุณสินธวัฒน์", "last_name": "สินธนบดี (อุทิศให้คุณพ่อสรโชติ สินธนบดี)", "donation_amount": 1000},
    {"first_name": "คุณฐปนรรถ", "last_name": "ไพบูลย์สิน", "donation_amount": 1000},
    {"first_name": "คุณธนาพร", "last_name": "ศรีคล้าย", "donation_amount": 1000},
    {"first_name": "คุณรัตนา", "last_name": "ชินเวชกิจมงคล", "donation_amount": 1000},
    {"first_name": "คุณภัทรพล", "last_name": "ทรงวีรธรรม", "donation_amount": 1000},
    {"first_name": "คุณเบญจวรรณ", "last_name": "รุ่งเจริญชัย", "donation_amount": 1000},
    {"first_name": "คุณพงศกร", "last_name": "เล็งดี", "donation_amount": 1000},
    {"first_name": "คุณนฤภร", "last_name": "น้อยอ่ำ", "donation_amount": 1500},
    {"first_name": "คุณสุชานาถ", "last_name": "ศรีคล้าย", "donation_amount": 1000},
    {"first_name": "คุณมณฑิสา", "last_name": "เอี่ยมกระสินธุ์", "donation_amount": 1200},
    {"first_name": "คุณเมตตา", "last_name": "อินเทพา", "donation_amount": 1000},
    {"first_name": "คุณประยูร", "last_name": "พรมสอน", "donation_amount": 1000},
    {"first_name": "ครอบครัวทัพรุ่ง", "last_name": "", "donation_amount": 2000},
    {"first_name": "คุณนนทชัย", "last_name": "นนทกานันท์", "donation_amount": 1000},
    {"first_name": "คุณรุ่งทิพย์", "last_name": "ดีอุดมวงศา", "donation_amount": 1000},
    {"first_name": "คุณชวลิต", "last_name": "ดีอุดมวงศา", "donation_amount": 1000},
    {"first_name": "คุณพิมลรัตน์", "last_name": "โชติวัฒนะกุล", "donation_amount": 1000},
    {"first_name": "คุณพิชญุตม์", "last_name": "พุ่มแดง", "donation_amount": 1000},
    {"first_name": "คุณวรัญพงศ์", "last_name": "บุญศิริธรรมชัย", "donation_amount": 1000},
    {"first_name": "คุณอมรรัตน์", "last_name": "สุวถาวรสกุล", "donation_amount": 1000},
    {"first_name": "คุณรวิพร", "last_name": "ศรีสุภัค", "donation_amount": 2000},
    
    {"first_name": "คุณธีธัช", "last_name": "เชื้อประไพศิลป์", "donation_amount": 800},

    {"first_name": "คุณแสงสุริยา", "last_name": "โฉมทอง", "donation_amount": 500},
    {"first_name": "คุณยุพิน", "last_name": "แก้วปัญญา", "donation_amount": 500},
    {"first_name": "คุณณัฐยศ", "last_name": "ยวงศรี", "donation_amount": 500},
    {"first_name": "คุณวศิน", "last_name": "กำภูพงษ์", "donation_amount": 500},
    {"first_name": "คุณศรีสำอางค์", "last_name": "อัศวโกวิท", "donation_amount": 500},
    {"first_name": "คุณผาณิต", "last_name": "กีรติบำรุงพงศ์", "donation_amount": 500},
    {"first_name": "คุณศมนพรรณ", "last_name": "ตระกลพัฑฒนะ", "donation_amount": 500},
    {"first_name": "คุณกชกร", "last_name": "พรสุขสวัสดิ์", "donation_amount": 500},
    {"first_name": "คุณสริตา", "last_name": "โสหา", "donation_amount": 500},
    {"first_name": "คุณนพวัฒน์", "last_name": "วงศ์ปิยะสถิตย์", "donation_amount": 500},
    {"first_name": "คุณบุญช่วย", "last_name": "อุดมรัตนพรกุล", "donation_amount": 500},
    {"first_name": "คุณประภาพรรณ", "last_name": "อุดมรัตนพรกุล", "donation_amount": 500},
    
    {"first_name": "คุณอัคคพล", "last_name": "ไทยจรรยา", "donation_amount": 500},
    {"first_name": "คุณอรมนต์", "last_name": "จันทพันธ์", "donation_amount": 500},
    {"first_name": "คุณชินวัฒน์", "last_name": "เทพหัสดิน ณ อยุธยา", "donation_amount": 500},
    {"first_name": "คุณนนทวัฒน์", "last_name": "พิพัฒน์รุ่งเรือง", "donation_amount": 500},
    {"first_name": "คุณเพ็ญลักษณ์", "last_name": "โล่ธุวาชัย", "donation_amount": 500},
    {"first_name": "คุณวสกร", "last_name": "อยู่ทรัพย์", "donation_amount": 500},
    {"first_name": "คุณณภัชนันท์", "last_name": "จงมั่นคง", "donation_amount": 519},
    {"first_name": "คุณกัลยา", "last_name": "กอบกำ", "donation_amount": 500},
    {"first_name": "คุณปริศนา", "last_name": "ศิลารักษ์", "donation_amount": 500},
    {"first_name": "คุณชลิสา", "last_name": "กัลยาณมิตร", "donation_amount": 500},
    {"first_name": "คุณจิราภร", "last_name": "หันตุลา", "donation_amount": 500},
    
]

df = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 127
#       1 data = [
#       2
#       3     {"first_name": "คุณศรัณย์", "last_name": "ธำรงรัตน์ (งานโครงสร้างและฐานราก)", "donation_amount": 10007},
#    (...)    124
#     125 ]
# --> 127 df = pd.DataFrame(data)
#
# NameError: name 'pd' is not defined

# %%
df.loc[df['donation_amount'] >= 500, 'type'] = 'ประธาน' # กรณีรวม
df.loc[df['donation_amount'] >= 1000, 'type'] = 'ประธาน'
df.loc[df['donation_amount'] >= 3000, 'type'] = 'รองประธานอุปถัมภ์'
df.loc[df['donation_amount'] >= 5000, 'type'] = 'ประธานอุปถัมภ์'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df.loc[df['donation_amount'] >= 500, 'type'] = 'ประธาน' # กรณีรวม
#       2 df.loc[df['donation_amount'] >= 1000, 'type'] = 'ประธาน'
#       3 df.loc[df['donation_amount'] >= 3000, 'type'] = 'รองประธานอุปถัมภ์'
#
# NameError: name 'df' is not defined

# %%
# 1. สร้าง Column พิเศษสำหรับให้ลำดับพระสงฆ์ขึ้นก่อน (สมมติว่าเช็คจากคำนำหน้า)
df['is_monk'] = df['first_name'].str.startswith('พระ').astype(int)

# 2. เรียงลำดับโดยให้ความสำคัญกับ: 
# ยอดเงิน (มากไปน้อย) -> ความเป็นพระ (พระขึ้นก่อนในยอดเงินที่ใกล้เคียงกัน) -> ชื่อ (ก-ฮ)
df = df.sort_values(
    by=["donation_amount", "is_monk", "first_name", "last_name"],
    ascending=[False, False, True, True]
)

# 3. ลบ Column พิเศษออกก่อนนำไปใช้งาน
df = df.drop(columns=['is_monk'])

# %%
df = reset(df)

# %%
df.to_csv('data.csv', index = False)

# %%
df.shape
# Out:
# (109, 4)

# %%
df['donation_amount'].sum()
# Out:
# np.float64(232188.6)

# %%
# df.head(30)

# %%
# git commit -a -m "update"
# git push -u origin --all
