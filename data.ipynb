# %%
#Default
import pandas as pd
pd.options.display.float_format = '{:,}'.format
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
def reset(df):
    cols = df.columns
    return df.reset_index()[cols]
def print_counts(df):
    cols = df.columns
    for each in cols:
        print(each)
        print(df[each].value_counts())
        print('______________________________________')

# ~
#Default Ending

# %%
data = [
    {"first_name": "คุณณัฐวัฒน์", "last_name": "เมืองจีน", "donation_amount": 10000},
    {"first_name": "คุณสืบพงษ์", "last_name": "ชัยวนนท์", "donation_amount": 6000},
    {"first_name": "คุณวีริศ", "last_name": "จันทราทิพย์", "donation_amount": 5900},
    {"first_name": "คุณภาวิน", "last_name": "จันทราทิพย์", "donation_amount": 5900},
    {"first_name": "คุณสคุณพจน์", "last_name": "ธนาโรจน์โสภณ", "donation_amount": 5800},
    {"first_name": "คุณนิธิพัฒน์", "last_name": "ภัททกัป", "donation_amount": 5700},
    {"first_name": "คุณธนัชชนม์", "last_name": "จงมั่นคง", "donation_amount": 5600},

    {"first_name": "คุณภาณุวัฒน์", "last_name": "พุฒพรึก (อุทิศให้น้องธนพล พุฒพรึก)", "donation_amount": 3000},
    {"first_name": "คุณศิวัช", "last_name": "พึ่งเจษฎา", "donation_amount": 3000},
    {"first_name": "คุณธนะรัชฏ์", "last_name": "พฤกษ์พระกานต์", "donation_amount": 3000},
    
    {"first_name": "คุณอรปภา", "last_name": "กาญจนาคม", "donation_amount": 1000},
    {"first_name": "คุณกนกกาญจน์", "last_name": "เหลี่ยมพันธุ์", "donation_amount": 1000},
    {"first_name": "คุณปรเมษฐ", "last_name": "วิสุทธิธรรม", "donation_amount": 1050},
    {"first_name": "คุณเฉลิมเกียรติ", "last_name": "สิรชัยรัตน์", "donation_amount": 1000},
    {"first_name": "คุณธนกฤต", "last_name": "วิลาสมงคลชัย", "donation_amount": 1000},
    {"first_name": "คุณแสงสุริยา", "last_name": "โฉมทอง", "donation_amount": 1000},
    {"first_name": "คุณดนยา", "last_name": "ทนงจิตร", "donation_amount": 1000},
    {"first_name": "พระธวัชชัย", "last_name": "กิติชัยวัฒน์ (อภิธโช)", "donation_amount": 1000},
    {"first_name": "คุณสุสาคร", "last_name": "มิ่งมูล", "donation_amount": 1000},     
]

df = pd.DataFrame(data)

# %%
df.loc[df['donation_amount'] >= 1000, 'type'] = 'ประธาน'
df.loc[df['donation_amount'] >= 3000, 'type'] = 'รองประธานอุปถัมภ์'
df.loc[df['donation_amount'] >= 5000, 'type'] = 'ประธานอุปถัมภ์'

# %%
df = df.sort_values(
    by=["donation_amount", "last_name", "first_name"],
    ascending=[False, True, True]
)

# %%
df = reset(df)

# %%
df.to_csv('data.csv', index = False)

# %%
df
# Out:
#          first_name                           last_name  donation_amount  \
# 0       คุณณัฐวัฒน์                            เมืองจีน            10000
# 1        คุณสืบพงษ์                            ชัยวนนท์             6000
# 2          คุณภาวิน                         จันทราทิพย์             5900
# 3          คุณวีริศ                         จันทราทิพย์             5900
# 4       คุณสคุณพจน์                        ธนาโรจน์โสภณ             5800
# 5      คุณนิธิพัฒน์                             ภัททกัป             5700
# 6       คุณธนัชชนม์                            จงมั่นคง             5600
# 7       คุณธนะรัชฏ์                       พฤกษ์พระกานต์             3000
# 8          คุณศิวัช                           พึ่งเจษฎา             3000
# 9      คุณภาณุวัฒน์  พุฒพรึก (อุทิศให้น้องธนพล พุฒพรึก)             3000
# 10        คุณปรเมษฐ                         วิสุทธิธรรม             1050
# 11         คุณอรปภา                            กาญจนาคม             1000
# 12       พระธวัชชัย               กิติชัยวัฒน์ (อภิธโช)             1000
# 13          คุณดนยา                             ทนงจิตร             1000
# 14        คุณสุสาคร                             มิ่งมูล             1000
# 15         คุณธนกฤต                        วิลาสมงคลชัย             1000
# 16  คุณเฉลิมเกียรติ                         สิรชัยรัตน์             1000
# 17     คุณกนกกาญจน์                       เหลี่ยมพันธุ์             1000
# 18     คุณแสงสุริยา                              โฉมทอง             1000
#
#                  type
# 0      ประธานอุปถัมภ์
# 1      ประธานอุปถัมภ์
# 2      ประธานอุปถัมภ์
# 3      ประธานอุปถัมภ์
# 4      ประธานอุปถัมภ์
# 5      ประธานอุปถัมภ์
# 6      ประธานอุปถัมภ์
# 7   รองประธานอุปถัมภ์
# 8   รองประธานอุปถัมภ์
# 9   รองประธานอุปถัมภ์
# 10             ประธาน
# 11             ประธาน
# 12             ประธาน
# 13             ประธาน
# 14             ประธาน
# 15             ประธาน
# 16             ประธาน
# 17             ประธาน
# 18             ประธาน
